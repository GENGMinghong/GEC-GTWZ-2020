# %%
import errant
import pandas as pd
import difflib

# %%
def get_diff(a,b):
    if len(a)>len(b): 
        res=''.join(a.split(b))             
    else: 
        res=''.join(b.split(a))             
    return res.strip()

# %%
punctuation = ['.',',','!','?','..','...','-']

# %%
def error_type(s1,s2):
    annotator = errant.load('en')
    orig = annotator.parse(s1)
    cor = annotator.parse(s2)
    edits = annotator.annotate(orig, cor)
    for e in edits:
        if 'DET' in e.type:
            return 'Articles'
        elif 'PREP' in e.type or 'PART' in e.type:
            return 'Preposition'
        elif 'PUNCT' in e.type or (e.o_str!='' and e.c_str!='' and get_diff(e.o_str,e.c_str) in punctuation) or ('-' in e.o_str or '-' in e.c_str):
            return 'Punctuation'
        elif 'VERB' in e.type:
            if 'SVA' in e.type:
                return 'Subject Verb Agreement'
            else:
                return 'Verb Form'
        elif 'NOUN' in e.type or 'ADJ' in e.type or 'MORPH' in e.type:
            return 'Word Form'
        else:
            return 'Other'

# %%
def get_action(s1,s2):
    annotator = errant.load('en')
    orig = annotator.parse(s1)
    cor = annotator.parse(s2)
    edits = annotator.annotate(orig, cor)
    for e in edits:
        if 'R:' in e.type:
            return 'replace'
        elif 'M:' in e.type:
            return 'insert'
        elif 'U:' in e.type:
            return 'remove'

# %%
def get_expla(s1,s2):
    annotator = errant.load('en')
    orig = annotator.parse(s1)
    cor = annotator.parse(s2)
    edits = annotator.annotate(orig, cor)
    if error_type(s1,s2)=='Verb Form':
        for e in edits:
            if 'TENSE' in e.type:
                return 'Verb Tense Error'
            elif 'FORM' in e.type:
                return 'Verb Form error'
            else:
                return 'Other verb error'
    elif error_type(s1,s2)=='Word Form':
        for e in edits:
            if 'NUM' in e.type:
                return 'Noun Number error'
            elif 'ADJ' in e.type:
                return 'Adjective error'
            elif 'MORPH' in e.type:
                return 'Morphology error'
            else:
                return 'Other word form error'

# %%
data = pd.read_csv('ErrorData.csv')

# %%
data['give_action'] = data.apply(lambda x: get_action(x.question, x.solution),axis=1)

# %%
data['give_category'] = data.apply(lambda x: error_type(x.question, x.solution),axis=1)

# %%
data.head(30)
# Out:
#     questionid                category  round  \
# 0            1                Articles      1
# 1            1                Articles      1
# 2            1                Articles      2
# 3            1                Articles      3
# 4            1                Articles      4
# 5            1             Preposition      1
# 6            1             Preposition      1
# 7            1             Preposition      2
# 8            1             Preposition      3
# 9            1             Preposition      4
# 10           1             Punctuation      1
# 11           1             Punctuation      1
# 12           1             Punctuation      2
# 13           1             Punctuation      3
# 14           1             Punctuation      4
# 15           1  Subject Verb Agreement      1
# 16           1  Subject Verb Agreement      1
# 17           1  Subject Verb Agreement      2
# 18           1  Subject Verb Agreement      3
# 19           1  Subject Verb Agreement      4
# 20           1               Verb Form      1
# 21           1               Verb Form      1
# 22           1               Verb Form      2
# 23           1               Verb Form      3
# 24           1               Verb Form      4
# 25           1               Word Form      0
# 26           1               Word Form      1
# 27           1               Word Form      1
# 28           1               Word Form      2
# 29           1               Word Form      3
#
#                                              question  \
# 0   These devices generate huge amount of data tha...
# 1   Fashion items make up large portion of e-comme...
# 2   Firstly, increasing number of people are reviv...
# 3   In the recent years, the rise of technology in...
# 4   The Sugar Detox Diet, which aims to promote a ...
# 5   A study by ABI Research (2017) forecasted that...
# 6   One method to measure brand positioning would ...
# 7     I have researched on recent health food trends.
# 8   Board games help people to build up social ski...
# 9   The cost of a mobile phone can amount from $1000.
# 10  An organisation with family friendly policies ...
# 11  In comparison the Esplanade spends four times ...
# 12  To encourage entrepreneurship, SMU should star...
# 13  His writing style also, instils an urgency in ...
# 14  Critics would argue that gaming is no differen...
# 15  An explanation of the statistics are required ...
# 16  Even readers who uses AR will likely be amazed...
# 17  Both articles gives employers advice on how to...
# 18  The sources unanimously indicates that phone a...
# 19  Almost 20% of employees is looking for a new j...
# 20  It is forecasted that AR users will increase b...
# 21  This will incentivize them to be bold in their...
# 22  Statistics play an important role in improve t...
# 23  National Sleep Foundation (n.d. as cited in Ch...
# 24  Consultations are to be done in private to pre...
# 25  Excessive dieting and exercising can have a ne...
# 26  Both trends provide consumers with enjoyable e...
# 27  Many fast-fashion retailers have included pyja...
# 28  The rising incidences of stroke among young pe...
# 29  Magnetic masks received overwhelmingly positiv...
#
#                                              solution  \
# 0   These devices generate a huge amount of data t...
# 1   Fashion items make up a large portion of e-com...
# 2   Firstly, an increasing number of people are re...
# 3   In recent years, the rise of technology in the...
# 4   The Sugar Detox Diet, which aims to promote he...
# 5   A study by ABI Research (2017) forecasted that...
# 6   One method to measure brand positioning would ...
# 7        I have researched recent health food trends.
# 8   Board games help people to build social skills...
# 9     The cost of a mobile phone can amount to $1000.
# 10  An organisation with family-friendly policies ...
# 11  In comparison, the Esplanade spends four times...
# 12  To encourage entrepreneurship, SMU should star...
# 13  His writing style also instils an urgency in e...
# 14  Critics would argue that gaming is no differen...
# 15  An explanation of the statistics is required t...
# 16  Even readers who use AR will likely be amazed ...
# 17  Both articles give employers advice on how to ...
# 18  The sources unanimously indicate that phone ad...
# 19  Almost 20% of employees are looking for a new ...
# 20  It is forecasted that AR users will increase b...
# 21  This will incentivize them to be bold in their...
# 22  Statistics play an important role in improving...
# 23  National Sleep Foundation (n.d. as cited in Ch...
# 24  Consultations are to be done in private to pre...
# 25  Excessive dieting and exercising can have a ne...
# 26  Both trends provide consumers with enjoyable e...
# 27  Many fast-fashion retailers have included pyja...
# 28  The rising incidence of stroke among young peo...
# 29  Magnetic masks received overwhelmingly positiv...
#
#                                           explanation  type   action  \
# 0                                    Article required     C   insert
# 1   The word "portion" is a single, countable noun...    SP   insert
# 2                                    Article required     C   insert
# 3                                 No article required     C   remove
# 4                                 No article required     C   remove
# 5   Idiomatic expressions: will grow by and will g...     C   insert
# 6   Modals or modal auxiliary verbs (can, could, m...    SP   insert
# 7    No preposition required after research as a verb     C   remove
# 8   No preposition required because the direction ...     C   remove
# 9   Amount to means up to an amount, as in this case.     C  replace
# 10  hyphenate 'family' and 'friendly' because both...     C   insert
# 11  You need a comma after the transition phrase "...    SP   insert
# 12  hyphenate 'student' and 'run' because both wor...     C   insert
# 13                                Comma is not needed     C   remove
# 14  Comma Splice: Two independent clauses cannot b...     C  replace
# 15  "explanation" takes the singular form of the v...     C  replace
# 16       "readers" takes the plural form of the verb.    SP  replace
# 17      "articles" takes the plural form of the verb.     C  replace
# 18       "sources" takes the plural form of the verb.     C  replace
# 19     "employees" takes the plural form of the verb.     C  replace
# 20                                Simple future tense     C   insert
# 21  Use parallel structures to emphasize the conne...    SP   insert
# 22          Play an important role in doing something     C  replace
# 23  In a present perfect tense, the verb has is fo...     C  replace
# 24  Here, eavesdrop' (verb) is functioning as a no...     C  replace
# 25  "Dieting and exercising" are being treated as ...  Test  replace
# 26  "Entertainment" is an uncountable noun, so it ...     C  replace
# 27  To show similarity, -like can be added to noun...    SP  replace
# 28  "Incidence" is an uncountable noun, so it has ...     C  replace
# 29  "Feedback" is an uncountable noun, so it has n...     C  replace
#
#              give_category give_action
# 0                 Articles      insert
# 1                 Articles      insert
# 2                 Articles      insert
# 3                 Articles      remove
# 4                 Articles      remove
# 5              Preposition      insert
# 6                Verb Form      insert
# 7              Preposition      remove
# 8              Preposition      remove
# 9              Preposition     replace
# 10             Punctuation     replace
# 11             Punctuation     replace
# 12             Punctuation     replace
# 13             Punctuation     replace
# 14               Word Form     replace
# 15  Subject Verb Agreement     replace
# 16  Subject Verb Agreement     replace
# 17  Subject Verb Agreement     replace
# 18  Subject Verb Agreement     replace
# 19  Subject Verb Agreement     replace
# 20               Verb Form      insert
# 21               Verb Form      insert
# 22               Verb Form     replace
# 23               Verb Form     replace
# 24               Word Form     replace
# 25               Word Form     replace
# 26               Word Form     replace
# 27             Punctuation     replace
# 28               Word Form     replace
# 29               Word Form     replace

# %%
s1 = 'It is forecasted that AR users will increase by another 35% over the next 5 years and millennials play a large part in that (Madigan, 2016).'
s2 = 'It is forecasted that AR users will increase by another 35% over the next 5 years and millennials will play a large part in that (Madigan, 2016).'

# %%
get_expla(s1,s2)
# Out:
# 'Verb Tense Error'

# %%
s3 = 'The rising incidences of stroke among young people is an issue of concern.'
s4 = 'The rising incidence of stroke among young people is an issue of concern.'

# %%
get_expla(s3,s4)
# Out:
# 'Noun Number error'
